# %%
def greeting(name):
    print("hello", name)
greeting(('Haley'))
# Out:
# hello Haley

# %%
def print_age(age):
    print("I am", age , "year old")
print_age(50)
# Out:
# I am 50 year old

# %%
def greeting1(first_name, last_name, age):
    print("hello there, " + first_name+" "+last_name)
    print("I am " + str(age) +", years old")
greeting1("Archana", "Shah", "50")
# Out:
# hello there, Archana Shah
# I am 50, years old
